# %%
#imports
import os
import sys
import random
import warnings

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from tqdm import tqdm
from itertools import chain
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

from keras.models import Model, load_model
from keras.layers import Input
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K

import tensorflow as tf

# Set some parameters
BATCH_SIZE = 10 # the higher the better
IMG_WIDTH = 128 # for faster computing on kaggle
IMG_HEIGHT = 128 # for faster computing on kaggle
IMG_CHANNELS = 4

#SET PATHS TO DATA
TRAIN_PATH = './sample/'
#TEST_PATH = '../input/stage1_test/'

warnings.filterwarnings('ignore', category=UserWarning, module='skimage')
seed = 42
# Out:
# Using TensorFlow backend.

# %%
from PIL import Image
image1 = Image.open('./sample/rainview_Anchorage_346835_1911271700.png')
image2 = Image.open('./sample/rainview_Anchorage_346835_1911271800.png')
image3 = Image.open('./sample/rainview_Anchorage_346835_1911271900.png')
image4 = Image.open('./sample/rainview_Anchorage_346835_1911272000.png')
image5 = Image.open('./sample/rainview_Anchorage_346835_1911272100.png')
image6 = Image.open('./sample/rainview_Anchorage_346835_1911272200.png')
image7 = Image.open('./sample/rainview_Anchorage_346835_1911272300.png')
images = [image1, image2, image3, image4, image5,image6,image7 ]
image7
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=512x512 at 0x136BA1160>

# %%
X, Y = [np.zeros(3)], [np.zeros(1)]
X[0] = [image1,image2,image3]
Y[0] = image4

# %%
Y
# Out:
# [<PIL.PngImagePlugin.PngImageFile image mode=RGBA size=512x512 at 0x1128C76D8>]

# %% [markdown]
# #### Prepare Data

# %%
# Get train and test IDs
train_ids = next(os.walk(TRAIN_PATH))[2]
train_ids
#train_ids = next(os.walk(TRAIN_PATH))[1]
#test_ids = next(os.walk(TEST_PATH))[1]
#np.random.seed(10)
# Out:
# ['rainview_Anchorage_346835_1911271700.png',
#  'rainview_Anchorage_346835_1911280000.png',
#  'rainview_Anchorage_346835_1911271800.png',
#  'rainview_Anchorage_346835_1911272100.png',
#  'rainview_Anchorage_346835_1911272300.png',
#  'rainview_Anchorage_346835_1911271900.png',
#  'rainview_Anchorage_346835_1911272200.png',
#  'rainview_Anchorage_346835_1911272000.png']

# %%
# Get and resize train images and masks
X_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))#, dtype=np.bool)

print('Getting and resizing train images and masks ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(train_ids), total=len(train_ids)):
    path = TRAIN_PATH + id_
    img = imread(path)[:,:,:IMG_CHANNELS]
    #img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_train[n] = img
    mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
    #for mask_file in next(os.walk(path))[3]:
    mask_= imread(path)[:,:,:IMG_CHANNELS]/255
    #mask_ = imread(path)[:,:,1]/255
    mask_ = resize(mask_, (IMG_HEIGHT, IMG_WIDTH), mode='constant', 
                                      preserve_range=True)
    #mask_ = np.expand_dims(resize(mask_, (IMG_HEIGHT, IMG_WIDTH), mode='constant', 
                                      #preserve_range=True), axis=-1)
    #mask = np.maximum(mask, mask_)
    Y_train[n-1] = mask_
print('Done!')
# Out:
# Getting and resizing train images and masks ...
# 100%|██████████| 8/8 [00:00<00:00,  8.24it/s]
# Done!

# %%
# Get and resize test images
X_test = np.zeros((len(test_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
sizes_test = []
print('Getting and resizing test images ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(test_ids), total=len(test_ids)):
    path = TEST_PATH + id_
    img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
    sizes_test.append([img.shape[0], img.shape[1]])
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_test[n] = img

print('Done!')

# %%
# Check if training data looks all right
ix = random.randint(0, len(train_ids))
imshow(X_train[ix])
plt.show()
#imshow(X_train[ix+1]) #should be the target image for ix
#plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.show()

# %% [markdown]
# more steps possible:
# https://www.kaggle.com/c0conuts/unet-imagedatagenerator-lb-0-336

# %% [markdown]
# #### Create Model

# %%
# Define IoU metric
@tf.function
def mean_iou(y_true, y_pred):
    prec = []
    for t in np.arange(0.5, 1.0, 0.05):
        #y_pred_ = tf.to_int32(y_pred > t)
        y_pred_ = tf.cast(y_pred > t, dtype = tf.int32)
        score, up_opt = tf.metrics.MeanIoU(y_true, y_pred_, 2)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return K.mean(K.stack(prec), axis=0)

# %%
tf.executing_eagerly()
# Out:
# True

# %%
# Build U-Net model
inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
s = Lambda(lambda x: x / 255) (inputs)

c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (s)
c1 = Dropout(0.1) (c1)
c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c1)
p1 = MaxPooling2D((2, 2)) (c1)

c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p1)
c2 = Dropout(0.1) (c2)
c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c2)
p2 = MaxPooling2D((2, 2)) (c2)

c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p2)
c3 = Dropout(0.2) (c3)
c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c3)
p3 = MaxPooling2D((2, 2)) (c3)

c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p3)
c4 = Dropout(0.2) (c4)
c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c4)
p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p4)
c5 = Dropout(0.3) (c5)
c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c5)

u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same') (c5)
u6 = concatenate([u6, c4])
c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u6)
c6 = Dropout(0.2) (c6)
c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c6)

u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c6)
u7 = concatenate([u7, c3])
c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u7)
c7 = Dropout(0.2) (c7)
c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c7)

u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c7)
u8 = concatenate([u8, c2])
c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u8)
c8 = Dropout(0.1) (c8)
c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c8)

u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c8)
u9 = concatenate([u9, c1], axis=3)
c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u9)
c9 = Dropout(0.1) (c9)
c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c9)

outputs = Conv2D(4, (1, 1), activation='sigmoid') (c9)

model = Model(inputs=[inputs], outputs=[outputs])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['mae'])
#model.compile(optimizer='adam', loss='binary_crossentropy', metrics=[mean_iou])
model.summary()
# Out:
# Model: "model_9"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_9 (InputLayer)            (None, 128, 128, 4)  0
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 128, 128, 4)  0           input_9[0][0]
# __________________________________________________________________________________________________
# conv2d_153 (Conv2D)             (None, 128, 128, 16) 592         lambda_9[0][0]
# __________________________________________________________________________________________________
# dropout_73 (Dropout)            (None, 128, 128, 16) 0           conv2d_153[0][0]
# __________________________________________________________________________________________________
# conv2d_154 (Conv2D)             (None, 128, 128, 16) 2320        dropout_73[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_33 (MaxPooling2D) (None, 64, 64, 16)   0           conv2d_154[0][0]
# __________________________________________________________________________________________________
# conv2d_155 (Conv2D)             (None, 64, 64, 32)   4640        max_pooling2d_33[0][0]
# __________________________________________________________________________________________________
# dropout_74 (Dropout)            (None, 64, 64, 32)   0           conv2d_155[0][0]
# __________________________________________________________________________________________________
# conv2d_156 (Conv2D)             (None, 64, 64, 32)   9248        dropout_74[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_34 (MaxPooling2D) (None, 32, 32, 32)   0           conv2d_156[0][0]
# __________________________________________________________________________________________________
# conv2d_157 (Conv2D)             (None, 32, 32, 64)   18496       max_pooling2d_34[0][0]
# __________________________________________________________________________________________________
# dropout_75 (Dropout)            (None, 32, 32, 64)   0           conv2d_157[0][0]
# __________________________________________________________________________________________________
# conv2d_158 (Conv2D)             (None, 32, 32, 64)   36928       dropout_75[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_35 (MaxPooling2D) (None, 16, 16, 64)   0           conv2d_158[0][0]
# __________________________________________________________________________________________________
# conv2d_159 (Conv2D)             (None, 16, 16, 128)  73856       max_pooling2d_35[0][0]
# __________________________________________________________________________________________________
# dropout_76 (Dropout)            (None, 16, 16, 128)  0           conv2d_159[0][0]
# __________________________________________________________________________________________________
# conv2d_160 (Conv2D)             (None, 16, 16, 128)  147584      dropout_76[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_36 (MaxPooling2D) (None, 8, 8, 128)    0           conv2d_160[0][0]
# __________________________________________________________________________________________________
# conv2d_161 (Conv2D)             (None, 8, 8, 256)    295168      max_pooling2d_36[0][0]
# __________________________________________________________________________________________________
# dropout_77 (Dropout)            (None, 8, 8, 256)    0           conv2d_161[0][0]
# __________________________________________________________________________________________________
# conv2d_162 (Conv2D)             (None, 8, 8, 256)    590080      dropout_77[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_33 (Conv2DTran (None, 16, 16, 128)  131200      conv2d_162[0][0]
# __________________________________________________________________________________________________
# concatenate_33 (Concatenate)    (None, 16, 16, 256)  0           conv2d_transpose_33[0][0]
#                                                                  conv2d_160[0][0]
# __________________________________________________________________________________________________
# conv2d_163 (Conv2D)             (None, 16, 16, 128)  295040      concatenate_33[0][0]
# __________________________________________________________________________________________________
# dropout_78 (Dropout)            (None, 16, 16, 128)  0           conv2d_163[0][0]
# __________________________________________________________________________________________________
# conv2d_164 (Conv2D)             (None, 16, 16, 128)  147584      dropout_78[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_34 (Conv2DTran (None, 32, 32, 64)   32832       conv2d_164[0][0]
# __________________________________________________________________________________________________
# concatenate_34 (Concatenate)    (None, 32, 32, 128)  0           conv2d_transpose_34[0][0]
#                                                                  conv2d_158[0][0]
# __________________________________________________________________________________________________
# conv2d_165 (Conv2D)             (None, 32, 32, 64)   73792       concatenate_34[0][0]
# __________________________________________________________________________________________________
# dropout_79 (Dropout)            (None, 32, 32, 64)   0           conv2d_165[0][0]
# __________________________________________________________________________________________________
# conv2d_166 (Conv2D)             (None, 32, 32, 64)   36928       dropout_79[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_35 (Conv2DTran (None, 64, 64, 32)   8224        conv2d_166[0][0]
# __________________________________________________________________________________________________
# concatenate_35 (Concatenate)    (None, 64, 64, 64)   0           conv2d_transpose_35[0][0]
#                                                                  conv2d_156[0][0]
# __________________________________________________________________________________________________
# conv2d_167 (Conv2D)             (None, 64, 64, 32)   18464       concatenate_35[0][0]
# __________________________________________________________________________________________________
# dropout_80 (Dropout)            (None, 64, 64, 32)   0           conv2d_167[0][0]
# __________________________________________________________________________________________________
# conv2d_168 (Conv2D)             (None, 64, 64, 32)   9248        dropout_80[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_36 (Conv2DTran (None, 128, 128, 16) 2064        conv2d_168[0][0]
# __________________________________________________________________________________________________
# concatenate_36 (Concatenate)    (None, 128, 128, 32) 0           conv2d_transpose_36[0][0]
#                                                                  conv2d_154[0][0]
# __________________________________________________________________________________________________
# conv2d_169 (Conv2D)             (None, 128, 128, 16) 4624        concatenate_36[0][0]
# __________________________________________________________________________________________________
# dropout_81 (Dropout)            (None, 128, 128, 16) 0           conv2d_169[0][0]
# __________________________________________________________________________________________________
# conv2d_170 (Conv2D)             (None, 128, 128, 16) 2320        dropout_81[0][0]
# __________________________________________________________________________________________________
# conv2d_171 (Conv2D)             (None, 128, 128, 4)  68          conv2d_170[0][0]
# ==================================================================================================
# Total params: 1,941,300
# Trainable params: 1,941,300
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# #### Train

# %%
# Fit model
earlystopper = EarlyStopping(patience=3, verbose=1)
checkpointer = ModelCheckpoint('model-w251weather-1.h5', verbose=1, save_best_only=True)
results = model.fit(X_train, Y_train, validation_split=0.1, batch_size=16, epochs=50, 
                    callbacks=[earlystopper, checkpointer])
#results = model.fit_generator(train_generator, validation_data=val_generator, validation_steps=10, steps_per_epoch=250,
 #                             epochs=3, callbacks=[earlystopper, checkpointer])
# Out:
# Train on 7 samples, validate on 1 samples
# Epoch 1/50
# 7/7 [==============================] - 3s 358ms/step - loss: 0.7359 - mae: 0.4363 - val_loss: 0.6694 - val_mae: 0.4153
#
# Epoch 00001: val_loss improved from inf to 0.66943, saving model to model-w251weather-1.h5
# Epoch 2/50
# 7/7 [==============================] - 1s 160ms/step - loss: 0.6811 - mae: 0.4110 - val_loss: 0.5892 - val_mae: 0.3675
#
# Epoch 00002: val_loss improved from 0.66943 to 0.58924, saving model to model-w251weather-1.h5
# Epoch 3/50
# 7/7 [==============================] - 1s 213ms/step - loss: 0.6128 - mae: 0.3648 - val_loss: 0.5123 - val_mae: 0.3206
#
# Epoch 00003: val_loss improved from 0.58924 to 0.51233, saving model to model-w251weather-1.h5
# Epoch 4/50
# 7/7 [==============================] - 1s 173ms/step - loss: 0.5282 - mae: 0.3159 - val_loss: 0.4196 - val_mae: 0.2189
#
# Epoch 00004: val_loss improved from 0.51233 to 0.41957, saving model to model-w251weather-1.h5
# Epoch 5/50
# 7/7 [==============================] - 1s 200ms/step - loss: 0.5549 - mae: 0.2503 - val_loss: 0.5096 - val_mae: 0.3085
#
# Epoch 00005: val_loss did not improve from 0.41957
# Epoch 6/50
# 7/7 [==============================] - 1s 144ms/step - loss: 0.4845 - mae: 0.2839 - val_loss: 0.4545 - val_mae: 0.2710
#
# Epoch 00006: val_loss did not improve from 0.41957
# Epoch 7/50
# 7/7 [==============================] - 1s 143ms/step - loss: 0.4504 - mae: 0.2606 - val_loss: 0.3688 - val_mae: 0.2033
#
# Epoch 00007: val_loss improved from 0.41957 to 0.36876, saving model to model-w251weather-1.h5
# Epoch 8/50
# 7/7 [==============================] - 1s 136ms/step - loss: 0.3892 - mae: 0.2102 - val_loss: 0.3497 - val_mae: 0.1646
#
# Epoch 00008: val_loss improved from 0.36876 to 0.34974, saving model to model-w251weather-1.h5
# Epoch 9/50
# 7/7 [==============================] - 1s 147ms/step - loss: 0.3914 - mae: 0.1822 - val_loss: 0.3375 - val_mae: 0.1513
#
# Epoch 00009: val_loss improved from 0.34974 to 0.33745, saving model to model-w251weather-1.h5
# Epoch 10/50
# 7/7 [==============================] - 1s 169ms/step - loss: 0.3645 - mae: 0.1652 - val_loss: 0.3301 - val_mae: 0.1480
#
# Epoch 00010: val_loss improved from 0.33745 to 0.33012, saving model to model-w251weather-1.h5
# Epoch 11/50
# 7/7 [==============================] - 1s 164ms/step - loss: 0.3490 - mae: 0.1602 - val_loss: 0.3310 - val_mae: 0.1483
#
# Epoch 00011: val_loss did not improve from 0.33012
# Epoch 12/50
# 7/7 [==============================] - 1s 172ms/step - loss: 0.3448 - mae: 0.1600 - val_loss: 0.3305 - val_mae: 0.1462
#
# Epoch 00012: val_loss did not improve from 0.33012
# Epoch 13/50
# 7/7 [==============================] - 1s 168ms/step - loss: 0.3403 - mae: 0.1574 - val_loss: 0.3274 - val_mae: 0.1412
#
# Epoch 00013: val_loss improved from 0.33012 to 0.32739, saving model to model-w251weather-1.h5
# Epoch 14/50
# 7/7 [==============================] - 1s 162ms/step - loss: 0.3313 - mae: 0.1515 - val_loss: 0.3260 - val_mae: 0.1362
#
# Epoch 00014: val_loss improved from 0.32739 to 0.32596, saving model to model-w251weather-1.h5
# Epoch 15/50
# 7/7 [==============================] - 1s 149ms/step - loss: 0.3272 - mae: 0.1472 - val_loss: 0.3213 - val_mae: 0.1321
#
# Epoch 00015: val_loss improved from 0.32596 to 0.32130, saving model to model-w251weather-1.h5
# Epoch 16/50
# 7/7 [==============================] - 1s 160ms/step - loss: 0.3268 - mae: 0.1450 - val_loss: 0.3104 - val_mae: 0.1289
#
# Epoch 00016: val_loss improved from 0.32130 to 0.31040, saving model to model-w251weather-1.h5
# Epoch 17/50
# 7/7 [==============================] - 1s 174ms/step - loss: 0.3198 - mae: 0.1422 - val_loss: 0.3033 - val_mae: 0.1292
#
# Epoch 00017: val_loss improved from 0.31040 to 0.30328, saving model to model-w251weather-1.h5
# Epoch 18/50
# 7/7 [==============================] - 1s 145ms/step - loss: 0.3139 - mae: 0.1412 - val_loss: 0.3013 - val_mae: 0.1314
#
# Epoch 00018: val_loss improved from 0.30328 to 0.30126, saving model to model-w251weather-1.h5
# Epoch 19/50
# 7/7 [==============================] - 1s 154ms/step - loss: 0.3136 - mae: 0.1419 - val_loss: 0.2955 - val_mae: 0.1290
#
# Epoch 00019: val_loss improved from 0.30126 to 0.29552, saving model to model-w251weather-1.h5
# Epoch 20/50
# 7/7 [==============================] - 1s 133ms/step - loss: 0.3093 - mae: 0.1389 - val_loss: 0.2875 - val_mae: 0.1232
#
# Epoch 00020: val_loss improved from 0.29552 to 0.28752, saving model to model-w251weather-1.h5
# Epoch 21/50
# 7/7 [==============================] - 1s 153ms/step - loss: 0.3047 - mae: 0.1333 - val_loss: 0.2814 - val_mae: 0.1219
#
# Epoch 00021: val_loss improved from 0.28752 to 0.28141, saving model to model-w251weather-1.h5
# Epoch 22/50
# 7/7 [==============================] - 1s 132ms/step - loss: 0.3015 - mae: 0.1317 - val_loss: 0.2780 - val_mae: 0.1264
#
# Epoch 00022: val_loss improved from 0.28141 to 0.27798, saving model to model-w251weather-1.h5
# Epoch 23/50
# 7/7 [==============================] - 1s 177ms/step - loss: 0.2956 - mae: 0.1323 - val_loss: 0.2742 - val_mae: 0.1259
#
# Epoch 00023: val_loss improved from 0.27798 to 0.27418, saving model to model-w251weather-1.h5
# Epoch 24/50
# 7/7 [==============================] - 1s 167ms/step - loss: 0.2901 - mae: 0.1305 - val_loss: 0.2641 - val_mae: 0.1175
#
# Epoch 00024: val_loss improved from 0.27418 to 0.26411, saving model to model-w251weather-1.h5
# Epoch 25/50
# 7/7 [==============================] - 1s 158ms/step - loss: 0.2890 - mae: 0.1250 - val_loss: 0.2789 - val_mae: 0.1290
#
# Epoch 00025: val_loss did not improve from 0.26411
# Epoch 26/50
# 7/7 [==============================] - 1s 150ms/step - loss: 0.2831 - mae: 0.1262 - val_loss: 0.2974 - val_mae: 0.1403
#
# Epoch 00026: val_loss did not improve from 0.26411
# Epoch 27/50
# 7/7 [==============================] - 1s 159ms/step - loss: 0.2831 - mae: 0.1281 - val_loss: 0.2586 - val_mae: 0.1095
#
# Epoch 00027: val_loss improved from 0.26411 to 0.25862, saving model to model-w251weather-1.h5
# Epoch 28/50
# 7/7 [==============================] - 1s 156ms/step - loss: 0.2903 - mae: 0.1204 - val_loss: 0.2615 - val_mae: 0.1142
#
# Epoch 00028: val_loss did not improve from 0.25862
# Epoch 29/50
# 7/7 [==============================] - 1s 132ms/step - loss: 0.2851 - mae: 0.1226 - val_loss: 0.2785 - val_mae: 0.1264
#
# Epoch 00029: val_loss did not improve from 0.25862
# Epoch 30/50
# 7/7 [==============================] - 1s 182ms/step - loss: 0.2847 - mae: 0.1265 - val_loss: 0.2811 - val_mae: 0.1282
#
# Epoch 00030: val_loss did not improve from 0.25862
# Epoch 00030: early stopping

# %% [markdown]
# #### Predict

# %%
# Predict on train, val and test
model = load_model('model-w251weather-1.h5',  custom_objects={'mean_iou': tf.keras.metrics.MeanIoU(num_classes=2)})
preds_train = model.predict(X_train[:int(X_train.shape[0]*0.9)], verbose=1)
preds_val = model.predict(X_train[int(X_train.shape[0]*0.9):], verbose=1)
#preds_test = model.predict(X_test, verbose=1)

# Threshold predictions
#preds_train_t = (preds_train > 0.5).astype(np.uint8)
#preds_val_t = (preds_val > 0.5).astype(np.uint8)
#preds_test_t = (preds_test > 0.5).astype(np.uint8)

# Create list of upsampled test masks
#preds_test_upsampled = []
#for i in range(len(preds_test)):
  #  preds_test_upsampled.append(resize(np.squeeze(preds_test[i]), 
          #                             (sizes_test[i][0], sizes_test[i][1]), 
           #                            mode='constant', preserve_range=True))
# Out:
# 7/7 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 60ms/step

# %%
# Perform a sanity check on some random training samples
ix = random.randint(0, len(preds_train_t))
imshow(X_train[ix])
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.show()
#imshow(np.squeeze(preds_train_t[ix]))
imshow(np.squeeze(preds_train[ix]))
plt.show()
#imshow(X_train[ix+1])
#plt.show()

# %%
# Perform a sanity check on some random validation samples
ix = random.randint(0, len(preds_val_t))
imshow(X_train[int(X_train.shape[0]*0.9):][ix])
plt.show()
imshow(np.squeeze(Y_train[int(Y_train.shape[0]*0.9):][ix]))
plt.show()
imshow(np.squeeze(preds_val_t[ix]))
plt.show()
